# %% [markdown]
# # Clone ViDubb Repository

# %%
import os
import shutil
import subprocess

# Set the path where you want to clone the repository
repo_dir = "ViDubb"

# Check if the directory exists
if os.path.exists(repo_dir):
    print("Directory exists. Deleting it...")
    shutil.rmtree(repo_dir)  # Deletes the directory and its contents

# Clone the repository
repo_url = "https://github.com/medahmedkrichen/ViDubb.git"
print(f"Cloning repository from {repo_url}...")
subprocess.run(["git", "clone", repo_url])
# Out:
# Directory exists. Deleting it...
# Cloning repository from https://github.com/medahmedkrichen/ViDubb.git...
# Cloning into 'ViDubb'...
# CompletedProcess(args=['git', 'clone', 'https://github.com/medahmedkrichen/ViDubb.git'], returncode=0)

# %% [markdown]
# # Configuration

# %%
# Update the HF_TOKEN value (required)
env_file_path = 'ViDubb/.env'
with open(env_file_path, 'r') as file:
    lines = file.readlines()


new_token = "your_hf_token_here"
for i, line in enumerate(lines):
    if line.startswith('HF_TOKEN'):
        lines[i] = f'HF_TOKEN={new_token}\n'

# Write the updated lines back to the .env file
with open(env_file_path, 'w') as file:
    file.writelines(lines)



# Update the Groq_TOKEN value (optional)
env_file_path = 'ViDubb/.env'

# Read the contents of the .env file
with open(env_file_path, 'r') as file:
    lines = file.readlines()

new_token = "your_groq_token_here"
for i, line in enumerate(lines):
    if line.startswith('Groq_TOKEN '):
        lines[i] = f'Groq_TOKEN ={new_token}\n'

# Write the updated lines back to the .env file
with open(env_file_path, 'w') as file:
    file.writelines(lines)
# Out:
# 'env_file_path = \'ViDubb/.env\'\n\n# Read the contents of the .env file\nwith open(env_file_path, \'r\') as file:\n    lines = file.readlines()\n\n# Update the HF_TOKEN value\nnew_token = "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"\nfor i, line in enumerate(lines):\n    if line.startswith(\'Groq_TOKEN \'):\n        lines[i] = f\'Groq_TOKEN ={new_token}\n\'\n\n# Write the updated lines back to the .env file\nwith open(env_file_path, \'w\') as file:\n    file.writelines(lines)'

# %%
# !pip install -r ViDubb/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 6.2 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 15.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.9.1
#     Uninstalling librosa-0.9.1:
#       Successfully uninstalled librosa-0.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.21.0 requires numpy==1.22.0; python_version <= "3.10", but you have numpy 1.26.4 which is incompatible.
# tts 0.21.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# tts 0.21.0 requires pandas<2.0,>=1.4, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
# !cd ViDubb && wget 'https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EdjI7bZlgApMqsVoEUUXpLsBxqXbn5z8VTmoxp55YNDcIA' -O 'Wav2Lip/wav2lip_gan.pth'
# !cd ViDubb && wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2024-12-11 22:52:56--  https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EdjI7bZlgApMqsVoEUUXpLsBxqXbn5z8VTmoxp55YNDcIA
# Resolving iiitaphyd-my.sharepoint.com (iiitaphyd-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8fa::10, ...
# Connecting to iiitaphyd-my.sharepoint.com (iiitaphyd-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 435801865 (416M) [application/octet-stream]
# Saving to: 'Wav2Lip/wav2lip_gan.pth'
#
# Wav2Lip/wav2lip_gan 100%[===================>] 415.61M   113MB/s    in 5.1s
#
# 2024-12-11 22:53:02 (82.1 MB/s) - 'Wav2Lip/wav2lip_gan.pth' saved [435801865/435801865]
#
# --2024-12-11 22:53:03--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# ...

# %% [markdown]
# # Run ViDubb

# %%
# !cd ViDubb/ && python inference.py --video_url "/kaggle/input/video2translate/Not Your Average 18 Year Old - Donald Trump OPENS UP About Baron Trump - Valuetainment (720p h264 youtube).mp4" --source_language "en" --target_language "fr" --LipSync True
# Out:
#
#
#
#                                   rvxQ
#            {^::_''';v     >,__'':'_'_'^l 2=:-----`-````...-;i.                c^:---_:=I     >;'---':"g
#            )_.i?II/.:c  z+-_%III"^?t]/.:;;`_yhghd44dddSpJtc/``^l              |`_fhht _c    Q;."qhhi ,d
#            j^.;1Lj1,.,7%,.;?jLe<`^I]I+````.=DQQ0SFpppqEkBQQH4['-=;...:^v1+,..`'.+DQQ1  ` .`,l' ?QQR) .` .-^I
#             t;.^1oo*_`:_.)1oo*;.`"ii\````` {00QY.      `^shQQQg=.=Lun\._:`;jnnv {00M?1fF2TI/.` wQQAczyF3Lr;`;c
#              s:."1tt%`._%ta1i```_?eer````` uQ0QS ```````.  4Q0QC {QQ0).`` xQQQI jQ008466G0QK#_.VQ0MkhpSOQQ&[.'%
#               %'.\[][\^{[[}/.```,!][\.````.hQ0Qe `````..  "O0QQ1 TQQ&'.`` 1QQD+ mQQZ"    cBQQ!:8QQF:   .oQQR> =.
#                >_.)??I}??%:.'|_."?I};````.;UQ0Rv ....._=%T$QQDj` gQQA=   +g0QY_'AQQG^   _1NQM%<MQQy_   ,wQQU/./.
#                 |--v***s|`-^lv-`>**l_```` vQQQQYPGGGGb8WQQHgu|._.ibQQKhp4ONQQp )MQQ$KEmV8QMXr 1QQM@8h6EHQBS\.;{
# ...
